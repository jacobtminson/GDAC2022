# %%
# %pip install vaderSentiment
# Out:
# ...
#      -------------------------------------- 126.0/126.0 KB 2.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 63.1/63.1 KB 3.3 MB/s eta 0:00:00
# ...
#      -------------------------------------- 149.2/149.2 KB 4.5 MB/s eta 0:00:00
# ...
#      -------------------------------------- 139.0/139.0 KB 4.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 61.2/61.2 KB 3.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\jacob\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np
import ast
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import os

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
Text = np.where(df['full_text']=='', df['text'],df['full_text'])

# %%
df[df['Ad Name'].str.contains('Amazon')].groupby('screen_name').count().sort_values('_id', ascending=False).head(10)
# Out:
#                  Unnamed: 0   _id  follower_count  location  Ad Name  \
# screen_name
# athome_campaign        3679  3679            3679         0     3679
# marialo04883049         440   440             440         0      440
# BotMasyer               397   397             397         0      397
# MiraiHappySALE          362   362             362         0      362
# AmazonHelp              257   257             257         0      257
# fixitfixitfixit         232   232             232         0      232
# NiceInfoBot             200   200             200       200      200
# Nblackthorne            197   197             197         0      197
# bmurphypointman         189   189             189       189      189
# fixittrackerca          183   183             183         0      183
#
#                  created_at  mediaType  lang  source  text  full_text  \
# screen_name
# athome_campaign        3679          0  3679    3679  3679       3679
# ...

# %%
df[df['lang']!='en'].groupby('Ad Name').mean('sentiment').sort_values('sentiment', ascending=False).head(10)
# Out:
#                                  Unnamed: 0  follower_count  mediaType  \
# Ad Name
# Amazon - Mind Reader           74026.614650     6072.355821        NaN
# Disney - MoonKnight           109156.437986     3704.135778        NaN
# Netflix - Adam                 20462.463571     4164.379751        NaN
# DraftKings - Gamble             1196.101083    14040.745487        NaN
# Toyota - Brothers                 51.571429    11140.857143        NaN
# UnversalPictures - Ambulance   20412.706361    18664.255998        NaN
# HBO - Lakers                    6650.442013    13768.859567        NaN
# CueHealth - SmartDevice          127.000000     2543.296703        NaN
# Google - Pixel                  1606.745318     1909.898876        NaN
# AMC+ - Promo                   28430.660128    12173.965734        NaN
#
#                               favorite_count  quote_count  reply_count  \
# Ad Name
# Amazon - Mind Reader                1.282200     0.068361     0.060695
# ...

# %%
dfText = pd.DataFrame(Text)

# %%
dfText = Text

# %%
dfText.to_csv('allText')

# %%
df = pd.read_csv('allAds.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2031877 entries, 0 to 2031876
# Data columns (total 20 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   Unnamed: 0.1             int64
#  1   _id                      object
#  2   screen_name              object
#  3   follower_count           int64
#  4   location                 object
#  5   Ad Name                  object
#  6   created_at               object
#  7   mediaType                float64
#  8   lang                     object
#  9   source                   object
#  10  text                     object
#  11  full_text                object
#  12  og_tweet_un              object
#  13  in_reply_to_screen_name  object
#  14  favorite_count           int64
#  15  quote_count              int64
#  16  reply_count              int64
#  17  retweet_count            int64
#  18  sentiment                float64
#  19  Unnamed: 0               float64
# ...

# %%
df[df['Ad Name']=='Wallbox - Supercharged'].count()
# Out:
# Unnamed: 0                 369
# _id                        369
# screen_name                369
# follower_count             369
# location                   291
# Ad Name                    369
# created_at                 369
# mediaType                    0
# lang                       369
# source                     369
# text                       369
# full_text                  347
# og_tweet_un                193
# in_reply_to_screen_name     41
# favorite_count             369
# quote_count                369
# reply_count                369
# retweet_count              369
# sentiment                  369
# Unnamed: 0.1               369
# dtype: int64

# %%
len(df['screen_name'].unique())
# Out:
# 840663

# %%
df[df['screen_name']=='Expedia'].sort_values('favorite_count', ascending=False).head(30)
# Out:
#          Unnamed: 0                       _id screen_name  follower_count  \
# 947452        64963  620a1b9dd4fa798ac304b6f9     Expedia          440314
# 1018839      136350  620a19e4d4fa798ac3033143     Expedia          440309
# 1023442      140953  620a19e4d4fa798ac303433e     Expedia          440309
# 952185        69696  620a1b9dd4fa798ac304c976     Expedia          440314
# 1025835      143346  620a19e4d4fa798ac3034c97     Expedia          440309
# 889329         6840  620a1b9dd4fa798ac303d3ee     Expedia          440313
# 963387        80898  620a19e4d4fa798ac30258a7     Expedia          440309
# 1010406      127917  620a19e4d4fa798ac3031052     Expedia          440310
# 938090        55601  620a1b9dd4fa798ac3049267     Expedia          440313
# 1085079       57124  620a1ca2d4fa798ac3062a47     Expedia          440315
# 1003995      121506  620a19e4d4fa798ac302f747     Expedia          440310
# 931365        48876  620a1b9dd4fa798ac3047822     Expedia          440313
# ...

# %%
df[df['source']== 'Arrow.'].head(30)
# Out:
#         Unnamed: 0                       _id    screen_name  follower_count  \
# 138489      138489  620a1bcad4fa798ac3051292  JurassicWorld          368823
# 241370       20424  620a2be8d4fa798ac31b5021  paramountplus          210867
# 242735       21789  620a2be8d4fa798ac31b5576  paramountplus          210867
# 246270       25324  620a2be8d4fa798ac31b6345  paramountplus          210867
# 252956       32010  620a2be8d4fa798ac31b7d63  paramountplus          210867
# 264947       44001  620a2bead4fa798ac31bac3a  paramountplus          210867
# 270718       49772  620a2bead4fa798ac31bc2c5  paramountplus          210867
# 780929      222810  620a1c01d4fa798ac30565c9  JurassicWorld          368823
# 872848         977  620a1d57d4fa798ac306eb1d     DraftKings          342813
# 873367        1496  620a1d57d4fa798ac306ed24     DraftKings          342813
# 873891        2020  620a1d57d4fa798ac306ef30     DraftKings          342813
# ...

# %%
df.describe().round(2)
# Out:
#        Unnamed: 0  follower_count  mediaType  favorite_count  quote_count  \
# count  2031877.00      2031877.00        0.0      2031877.00   2031877.00
# mean     55806.58        27574.34        NaN            3.00         0.16
# std      58309.96       352235.31        NaN          206.16        21.27
# min          0.00            0.00        NaN            0.00         0.00
# 25%      11853.00           56.00        NaN            0.00         0.00
# 50%      33530.00          243.00        NaN            0.00         0.00
# 75%      81585.00          836.00        NaN            0.00         0.00
# max     269050.00     60844524.00        NaN       111684.00     12506.00
#
#        reply_count  retweet_count   sentiment  Unnamed: 0.1
# count   2031877.00     2031877.00  2031877.00    2031877.00
# mean          0.21           0.57        0.22      55806.58
# std          15.64         118.21        0.44      58309.96
# min           0.00           0.00       -1.00          0.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2031877 entries, 0 to 2031876
# Data columns (total 20 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   Unnamed: 0               int64
#  1   _id                      object
#  2   screen_name              object
#  3   follower_count           int64
#  4   location                 object
#  5   Ad Name                  object
#  6   created_at               object
#  7   mediaType                float64
#  8   lang                     object
#  9   source                   object
#  10  text                     object
#  11  full_text                object
#  12  og_tweet_un              object
#  13  in_reply_to_screen_name  object
#  14  favorite_count           int64
#  15  quote_count              int64
#  16  reply_count              int64
#  17  retweet_count            int64
#  18  sentiment                float64
#  19  Unnamed: 0.1             float64
# ...

# %%
df.head()
# Out:
#                         _id      screen_name  follower_count  location  \
# 0  620a2584d4fa798ac31070e5        mirin1059             114  神奈川県 横浜市
# 1  620a2584d4fa798ac31070e6       hirorin_go             648       NaN
# 2  620a2584d4fa798ac31070e7  marialo04883049              26       NaN
# 3  620a2584d4fa798ac31070e8         reds_cat             691       NaN
# 4  620a2584d4fa798ac31070e9          kirry_v             214     お布団の中
#
#                 Ad Name           created_at lang               source  \
# 0  Amazon - Mind Reader  2022-02-14 02:59:59   ja   Twitter for iPhone
# 1  Amazon - Mind Reader  2022-02-14 02:59:59   ja      Twitter Web App
# 2  Amazon - Mind Reader  2022-02-14 02:59:59  und      Twitter Web App
# 3  Amazon - Mind Reader  2022-02-14 02:59:59   ja  Twitter for Android
# 4  Amazon - Mind Reader  2022-02-14 02:59:59   ja   Twitter for iPhone
#
# ...

# %%
df.groupby('screen_name').count().sort_values('_id',ascending=False).head(200).to_clipboard()

# %%
df['engagements'] = df['favorite_count']+ df['quote_count']+df['reply_count']+df['retweet_count']

# %%
df

# %%
most_engaged_ids = df.groupby('_id').sum().sort_values('engagements', ascending=False).head(20).index.to_list()

# %%
df.groupby('in_reply_to_screen_name').count().sort_values('reply_count',ascending=False).head(50)
# Out:
#                          Unnamed: 0    _id  screen_name  follower_count  \
# in_reply_to_screen_name
# MichelobULTRA                 24882  24882        24882           24882
# bookingcom                    21749  21749        21749           21749
# FTX_Official                  19580  19580        19580           19580
# SamsClub                      15331  15331        15331           15331
# ChesterCheetah                14488  14488        14488           14488
# LAYS                          14022  14022        14022           14022
# Expedia                       13709  13709        13709           13709
# Doritos                       13356  13356        13356           13356
# DojaCat                        6633   6633         6633            6633
# budlight                       6187   6187         6187            6187
# McDonalds                      5725   5725         5725            5725
# CutwaterSpirits                5575   5575         5575            5575
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2031877 entries, 0 to 2031876
# Data columns (total 21 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   Unnamed: 0               int64
#  1   _id                      object
#  2   screen_name              object
#  3   follower_count           int64
#  4   location                 object
#  5   Ad Name                  object
#  6   created_at               object
#  7   mediaType                float64
#  8   lang                     object
#  9   source                   object
#  10  text                     object
#  11  full_text                object
#  12  og_tweet_un              object
#  13  in_reply_to_screen_name  object
#  14  favorite_count           int64
#  15  quote_count              int64
#  16  reply_count              int64
#  17  retweet_count            int64
#  18  sentiment                float64
#  19  Unnamed: 0.1             float64
# ...

# %%
df.groupby('Ad Name').sum('engagements').sort_values('engagements', ascending=False).head(10)
# Out:
#                           Unnamed: 0  follower_count  mediaType  \
# Ad Name
# Disney - MoonKnight      36194085775       973139725        0.0
# CoinBase - Biggame        3135805221       551020606        0.0
# NBC - News                3179512896      2670909261        0.0
# McDonalds - Uhhhh        16908041886       686038049        0.0
# NBC - LawandOrder         2699251075      2595598696        0.0
# Amazon - Mind Reader     13958615070      1384709717        0.0
# AmazonPrimeVideo - LOTR   1429226380       238735888        0.0
# AMC+ - Promo              3081399756       546577229        0.0
# DisneyPlus - GOATS         999067350       192606175        0.0
# FTX - DontMiss           11310606406       162979981        0.0
#
#                          favorite_count  quote_count  reply_count  \
# Ad Name
# Disney - MoonKnight              953968        27331        26761
# CoinBase - Biggame               486320         7152        39093
# ...

# %%
df.groupby('Ad Name').sum('follower_count').sort_values('follower_count', ascending=False).head(100)
# Out:
#                                 Unnamed: 0  follower_count  mediaType  \
# Ad Name
# Crypto.com - Truth               776002710     31612332451        0.0
# Expedia - Travelheads          10580105845      8645360513        0.0
# NBC - News                      3179512896      2670909261        0.0
# NBC - LawandOrder               2699251075      2595598696        0.0
# Amazon - Mind Reader           13958615070      1384709717        0.0
# Disney - MoonKnight            36194085775       973139725        0.0
# Sams Club - VIP                  349338528       691930048        0.0
# McDonalds - Uhhhh              16908041886       686038049        0.0
# CoinBase - Biggame              3135805221       551020606        0.0
# AMC+ - Promo                    3081399756       546577229        0.0
# UnversalPictures - Ambulance     664100790       447358793        0.0
# Chevrolet - Newgen               548251941       386363035        0.0
# ...

# %%
df[]

# %%
df[(df['screen_name']=='FTX_Official')].head(30)
# Out:
#          Unnamed: 0                       _id   screen_name  follower_count  \
# 1222461      133568  620a1928d4fa798ac301e0b9  FTX_Official          566452
# 1896308         198  620a13bfd4fa798ac3fb22d6  FTX_Official          565574
#
#         location          Ad Name           created_at  mediaType lang  \
# 1222461      NaN   FTX - DontMiss  2022-02-14 01:05:38        NaN   en
# 1896308      NaN  T-Mobile - Hint  2022-02-14 02:47:09        NaN  und
#
#                        source  \
# 1222461  Twitter Media Studio
# 1896308       Twitter Web App
#
#                                                                                                                                                 text  \
# 1222461  The next ₿ig thing is here, even if Larry can’t see it.\n\nWe’re giving away 7.54 #bitcoin right now to celebrate!… https://t.co/g1gyiSOz2W
# ...

# %%
df[df['_id'].isin(most_engaged_ids)].sort_values('engagements',ascending=False)
# Out:
#                               _id    screen_name  follower_count  \
# 1222461  620a1928d4fa798ac301e0b9   FTX_Official          566452
# 1911668  620a244cd4fa798ac3100ca0        DojaCat         4424256
# 218681   620a23f0d4fa798ac30fdc39    LOTRonPrime          405472
# 198287   620a1f58d4fa798ac309a5c4    LOTRonPrime          405370
# 163921   620a1adbd4fa798ac303b5a1    LOTRonPrime          405276
# 440638   620a2260d4fa798ac30ca026        Snowden         5142872
# 1306236  620a26cdd4fa798ac314221e      McDonalds         4485677
# 293167   620a2bead4fa798ac31c1a76  MarvelStudios         8643127
# 826803   620a1f14d4fa798ac3093070  MarvelStudios         8642413
# 862897   620a1f14d4fa798ac3093070  MarvelStudios         8642413
# 780025   620a1ec7d4fa798ac308a14a  MarvelStudios         8642393
# 2018494  620a27f9d4fa798ac3164e83     KekePalmer         1980414
# 293184   620a2bead4fa798ac31c1a87  MarvelStudios         8643127
# ...

# %%
df[df['in_reply_to_screen_name']=='LOTRonPrime'].sort_values('follower_count', ascending=False).head(20)
# Out:
#                              _id      screen_name  follower_count  \
# 179859  620a1f58d4fa798ac3095dc8      amazonmusic         1979634
# 153676  620a1adbd4fa798ac3038d9c      amazonmusic         1979631
# 196891  620a1f58d4fa798ac309a050     PrimeVideoES          328128
# 162896  620a1adbd4fa798ac303b1a0     PrimeVideoES          328110
# 170932  620a1f58d4fa798ac3093ae9          arvalis          138177
# 148375  620a1adbd4fa798ac30378e7          arvalis          138114
# 170198  620a1f58d4fa798ac309380b  YunalesckaGames           45217
# 147897  620a1adbd4fa798ac3037709  YunalesckaGames           45216
# 171039  620a1f58d4fa798ac3093b54     anthunesarth           35102
# 148444  620a1adbd4fa798ac303792c     anthunesarth           35102
# 193964  620a1f58d4fa798ac30994e1       giselleskr           33449
# 161295  620a1adbd4fa798ac303ab5f       giselleskr           33449
# 158172  620a1adbd4fa798ac3039f2c         NathieVR           30853
# ...

# %%
df[df['_id']=='620a1928d4fa798ac301e0b9'].sort_values('reply_count',ascending=False)
# Out:
#                               _id   screen_name  follower_count location  \
# 1222461  620a1928d4fa798ac301e0b9  FTX_Official          566452      NaN
#
#                 Ad Name           created_at lang                source  \
# 1222461  FTX - DontMiss  2022-02-14 01:05:38   en  Twitter Media Studio
#
#                                                                                                                                                 text  \
# 1222461  The next ₿ig thing is here, even if Larry can’t see it.\n\nWe’re giving away 7.54 #bitcoin right now to celebrate!… https://t.co/g1gyiSOz2W
#
#                                                                                                                                                                                                                                                                                                                              full_text  \
# ...

# %%
df.groupby('Ad Name').max().sort_values('reply_count', ascending=False)
# Out:
# C:\Users\jacob\AppData\Local\Temp/ipykernel_5260/904260907.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   df.groupby('Ad Name').max().sort_values('reply_count', ascending=False)
#                                Unnamed: 0                       _id  \
# Ad Name
# FTX - DontMiss                     150403  620a2624d4fa798ac3136a91
# Sams Club - VIP                     26432  620a2a54d4fa798ac319c1a8
# Lays - GoldenMemories               27329  620a23f5d4fa798ac30fe722
# Michelob - Organicseltzer           21336  620a2bfad4fa798ac31c3483
# Michelob - Gametime                 28549  620a2a04d4fa798ac319583a
# Amazon - Mind Reader               167084  620a2b32d4fa798ac31ae428
# AmazonPrimeVideo - LOTR             53464  620a27d5d4fa798ac3162696
# McDonalds - Uhhhh                  183891  620a2a58d4fa798ac319c394
# ...

# %%
df[df['Ad Name']=='PizzaHut - Dots'].sort_values('follower_count',ascending=False).head(50)
# Out:
#          Unnamed: 0                       _id      screen_name  \
# 1764477        1676  620a195cd4fa798ac3022afd          Twitter
# 1763513         712  620a195cd4fa798ac3022739            pepsi
# 1764867        2066  620a195cd4fa798ac3022c83            pepsi
# 1768343        5542  620a195cd4fa798ac3023a17            pepsi
# 1765843        3042  620a195cd4fa798ac3023053         pizzahut
# 1766485        3684  620a195cd4fa798ac30232d5         pizzahut
# 1767305        4504  620a195cd4fa798ac3023609         pizzahut
# 1764886        2085  620a195cd4fa798ac3022c96         pizzahut
# 1765908        3107  620a195cd4fa798ac3023094         pizzahut
# 1765142        2341  620a195cd4fa798ac3022d96         pizzahut
# 1764039        1238  620a195cd4fa798ac3022947         pizzahut
# 1763746         945  620a195cd4fa798ac3022822         pizzahut
# 1769531        6730  620a195cd4fa798ac3023ebb  Pizza_Hut_Japan
# 1765761        2960  620a195cd4fa798ac3023001  Pizza_Hut_Japan
# ...
